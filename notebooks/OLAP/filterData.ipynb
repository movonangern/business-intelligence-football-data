# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Verbindung zur Datenbank herstellen
engine = create_engine("mysql+mysqlconnector://root:root@localhost:3306/football_db", echo=False)

# %%
query_appearances = "SELECT * FROM appearances WHERE date >= '2021-01-01';"
df_appearances = pd.read_sql_query(query_appearances, engine)
df_appearances.head(10)
# Out:
#     appearance_id  game_id  player_id  player_club_id  player_current_club_id  \
# 0  3393783_106721  3393783     106721             370                    2553
# 1  3393783_120976  3393783     120976             370                     370
# 2  3393783_120977  3393783     120977             371                     371
# 3   3393783_12688  3393783      12688             371                     370
# 4  3393783_132207  3393783     132207             370                    2553
# 5  3393783_183161  3393783     183161             370                     370
# 6  3393783_186644  3393783     186644             371                     190
# 7  3393783_188077  3393783     188077             371                     989
# 8  3393783_195906  3393783     195906             371                     371
# 9   3393783_21306  3393783      21306             370                    2578
#
#          date          player_name competition_id  yellow_cards  red_cards  \
# ...

# %%
df_appearances.shape
# Out:
# (446793, 38)

# %%
query_club_games = "SELECT * FROM club_games WHERE game_id IN (SELECT game_id FROM games WHERE season >= 2021);"
df_club_games = pd.read_sql_query(query_club_games, engine)
df_club_games.head(10)
# Out:
#        id  game_id  club_id  own_goals  own_position     own_manager_name  \
# 0   64367  3573730     1082          1           NaN   Jocelyn Gourvennec
# 1  131052  3573730      583          0           NaN  Mauricio Pochettino
# 2   23330  3575344       16          1           NaN           Marco Rose
# 3   90015  3575344       27          3           NaN    Julian Nagelsmann
# 4   60208  3578075     1003          1           NaN      Brendan Rodgers
# 5  126893  3578075      281          0           NaN        Pep Guardiola
# 6   23331  3580162      865          1          10.0         Bo Henriksen
# 7   90016  3580162      173          2           2.0          Andreas Alm
# 8   10964  3580163     2778          1          11.0    Flemming Pedersen
# 9   77649  3580163     1063          2           3.0           Lars Friis
#
#    opponent_id  opponent_goals  opponent_position opponent_manager_name  \
# 0          583               0                NaN   Mauricio Pochettino
# ...

# %%
df_club_games.shape
# Out:
# (31942, 12)

# %%
query_clubs = "SELECT * FROM clubs;"
df_clubs = pd.read_sql_query(query_clubs, engine)
df_clubs.head(10)
# Out:
#    club_id            club_code                            name  \
# 0        3            1-fc-koln            1. Fußball-Club Köln
# 1        4        1-fc-nurnberg                  1.FC Nuremberg
# 2        5           ac-mailand       Associazione Calcio Milan
# 3        6            adanaspor                       Adanaspor
# 4       10    arminia-bielefeld               Arminia Bielefeld
# 5       11           fc-arsenal           Arsenal Football Club
# 6       12               as-rom      Associazione Sportiva Roma
# 7       13      atletico-madrid  Club Atlético de Madrid S.A.D.
# 8       15  bayer-04-leverkusen     Bayer 04 Leverkusen Fußball
# 9       16    borussia-dortmund               Borussia Dortmund
#
#   domestic_competition_id total_market_value  squad_size  average_age  \
# 0                      L1               None          29         25.0
# 1                      L1               None          33         25.0
# ...

# %%
df_clubs.shape
# Out:
# (426, 17)

# %%
query_competition = "SELECT * FROM competition;"
df_competition = pd.read_sql_query(query_competition, engine)
df_competition.head(10)
# Out:
#   competition_id                     competition_code  \
# 0            BE1                   jupiler-pro-league
# 1           BESC                     belgian-supercup
# 2            CDR                         copa-del-rey
# 3            CGB                              efl-cup
# 4            CIT                            italy-cup
# 5             CL                uefa-champions-league
# 6            CLQ  uefa-champions-league-qualifikation
# 7            DFB                            dfb-pokal
# 8            DFL                         dfl-supercup
# 9            DK1                          superligaen
#
#                                   name                          sub_type  \
# 0                   jupiler-pro-league                        first_tier
# 1                     belgian-supercup                domestic_super_cup
# 2                         copa-del-rey                      domestic_cup
# 3                              efl-cup                        league_cup
# ...

# %%
df_competition.shape
# Out:
# (43, 10)

# %%
query_game_events = "SELECT * FROM game_events WHERE game_id IN (SELECT game_id FROM games WHERE season >= 2021);"
df_game_events = pd.read_sql_query(query_game_events, engine)
df_game_events.head(10)
# Out:
#                       game_event_id        date  game_id  minute  \
# 0  1d01e32b2bd5d0629f4f600367664512  2021-08-01  3573730      71
# 1  2881fe99d9d50c18290ede6ffcd7312d  2021-08-01  3573730      79
# 2  3482ba581e53b74660f4b15ccfd68ef6  2021-08-01  3573730      45
# 3  96ea0817d233416a0cf4b898186fdca9  2021-08-01  3573730      81
# 4  9d1a937ab9e42daf4b8063b4a127fb2c  2021-08-01  3573730      76
# 5  b098b8427ba4bb76c4049fe6faaa6c2e  2021-08-01  3573730      85
# 6  b2b0f6ffcdcf2302c4b0cb00ef2d332d  2021-08-01  3573730      85
# 7  d7641d205d02cbed0b76e67a1045c11e  2021-08-01  3573730      81
# 8  08040928f279a6b15a9f7b31df1ee123  2021-08-17  3575344      41
# 9  1b1fc23efbf14d211b2dcfb795425348  2021-08-17  3575344      49
#
#             type  club_id  player_id                              description  \
# 0  Substitutions      583     536482                                     None
# 1  Substitutions     1082     290256                                     None
# ...

# %%
df_game_events.shape
# Out:
# (200297, 10)

# %%
query_game_lineups = "SELECT * FROM game_lineups WHERE game_id IN (SELECT game_id FROM games WHERE season >= 2021);"
df_game_lineups = pd.read_sql_query(query_game_lineups, engine)
df_game_lineups.head(10)
# Out:
#                     game_lineups_id  game_id  club_id             type  \
# 0  0986b2bf40d93e365939af5052e1f5f9  3573730     1082  starting_lineup
# 1  0ebb44f2a0d55bd56357f3ddd8977425  3573730      583  starting_lineup
# 2  11cc8eb76c94f03f845afa7176ab5ae9  3573730      583      substitutes
# 3  17fe27bca6029817abfccb739674a4be  3573730     1082  starting_lineup
# 4  1fceaed471d0aa9f6ec0695b3220b8a2  3573730     1082  starting_lineup
# 5  227a05be666b58ea7ffcc04bc33ec4cb  3573730     1082  starting_lineup
# 6  2831cb077d9a3cefc35f20093a899285  3573730     1082      substitutes
# 7  2960faf0e57c0e43e13f096de9e6e130  3573730     1082      substitutes
# 8  3230388abeab06f0b2450913be42b50a  3573730      583      substitutes
# 9  3d6e06aca83af67328b13c16ab0a47b5  3573730     1082      substitutes
#
#    number  player_id     player_name  team_captain          position
# 0    30.0     288415      Léo Jardim             0        Goalkeeper
# ...

# %%
df_game_lineups.shape
# Out:
# (648687, 9)

# %%
query_games = "SELECT * FROM games WHERE season >= 2021;"
df_games = pd.read_sql_query(query_games, engine)
df_games.head(10)
# Out:
#    game_id competition_id  season        round        date  home_club_id  \
# 0  3573730           FRCH    2021        Final  2021-08-01          1082
# 1  3575344            DFL    2021        Final  2021-08-17            16
# 2  3578075           GBCS    2021        Final  2021-08-07          1003
# 3  3580162            DK1    2021  1. Matchday  2021-07-16           865
# 4  3580163            DK1    2021  1. Matchday  2021-07-18          2778
# 5  3580164            DK1    2021  1. Matchday  2021-07-18           443
# 6  3580165            DK1    2021  1. Matchday  2021-07-18           190
# 7  3580166            DK1    2021  1. Matchday  2021-07-18           678
# 8  3580167            DK1    2021  1. Matchday  2021-07-19          1177
# 9  3580175            DK1    2021  2. Matchday  2021-07-24          1053
#
#    away_club_id  home_club_goals  away_club_goals  home_club_position  ...  \
# 0           583                1                0                 NaN  ...
# ...

# %%
df_games.shape
# Out:
# (15971, 23)

# %%
query_player_valuations = "SELECT * FROM player_valuations WHERE date >= '2021-01-01';"
df_player_valuations = pd.read_sql_query(query_player_valuations, engine)
df_player_valuations.head(10)
# Out:
#        id  player_id        date  market_value_in_eur  current_club_id  \
# 0  338248      38000  2021-01-01               150000             2861
# 1  338249      66613  2021-01-01               150000              441
# 2  338250      74253  2021-01-01                50000             1025
# 3  338251     106181  2021-01-01               250000             3558
# 4  338252     126673  2021-01-01              3500000             1025
# 5  338253     147490  2021-01-01                75000             1084
# 6  338254     262682  2021-01-01               150000              173
# 7  338255      28171  2021-01-02                75000             1084
# 8  338256      33448  2021-01-02                75000              130
# 9  338257      34116  2021-01-02                75000              173
#
#   player_club_domestic_competition_id
# 0                                 BE1
# 1                                 GR1
# 2                                 IT1
# ...

# %%
df_player_valuations.shape
# Out:
# (127074, 6)

# %%
query_players = "SELECT * FROM players;"
df_players = pd.read_sql_query(query_players, engine)
df_players.head(10)
# Out:
#    player_id first_name     last_name                 name  last_season  \
# 0         10   Miroslav         Klose       Miroslav Klose         2015
# 1         26      Roman  Weidenfeller   Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov     Dimitar Berbatov         2015
# 3         77       None         Lúcio                Lúcio         2012
# 4         80        Tom        Starke           Tom Starke         2017
# 5        109       None          Dedê                 Dedê         2013
# 6        123  Christoph     Metzelder  Christoph Metzelder         2012
# 7        132      Tomas       Rosicky        Tomas Rosicky         2015
# 8        162       Marc       Ziegler         Marc Ziegler         2012
# 9        215      Roque    Santa Cruz     Roque Santa Cruz         2015
#
#    current_club_id          player_code    country_of_birth   city_of_birth  \
# 0              398       miroslav-klose              Poland           Opole
# ...

# %%
df_players.shape
# Out:
# (30500, 23)

# %%
import os

# Erstelle den Ordner, wenn er nicht existiert
output_folder = "C:/Users/Richa/Desktop/business-intelligence-football-data/data/OLAP data"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Speichere jeden DataFrame als CSV in dem Ordner
df_appearances.to_csv(f"{output_folder}/df_appearances.csv", index=False)
df_club_games.to_csv(f"{output_folder}/df_club_games.csv", index=False)
df_clubs.to_csv(f"{output_folder}/df_clubs.csv", index=False)
df_competition.to_csv(f"{output_folder}/df_competition.csv", index=False)
df_game_events.to_csv(f"{output_folder}/df_game_events.csv", index=False)
df_game_lineups.to_csv(f"{output_folder}/df_game_lineups.csv", index=False)
df_games.to_csv(f"{output_folder}/df_games.csv", index=False)
df_player_valuations.to_csv(f"{output_folder}/df_player_valuations.csv", index=False)
df_players.to_csv(f"{output_folder}/df_players.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       6     os.makedirs(output_folder)
#       8 # Speichere jeden DataFrame als CSV in dem Ordner
# ----> 9 df_appearances.to_csv(f"{output_folder}/df_appearances.csv", index=False)
#      10 df_club_games.to_csv(f"{output_folder}/df_club_games.csv", index=False)
#      11 df_clubs.to_csv(f"{output_folder}/df_clubs.csv", index=False)
#
# NameError: name 'df_appearances' is not defined
